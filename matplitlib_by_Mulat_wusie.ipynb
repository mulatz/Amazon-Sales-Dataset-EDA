# %% [markdown]
# <a href="https://colab.research.google.com/github/mulatz/Amazon-Sales-Dataset-EDA/blob/main/matplitlib_by_Mulat_wusie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  let is introuduce what does it mean Visualization?
#  Visualization, in its simplest form, is the act of creating a mental image or scenario in your mind. It's a technique used to mentally rehearse or simulate an experience, often with the goal of achieving a desired outcome. Essentially, it's about "seeing" something in your mind before it happens in reality

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1,2,3]
y = [4,5,6]

# %%
plt.plot(x,y) #(1,4)(2,5)(3,6)
plt.grid()
plt.show()

# %% [markdown]
# # Univariate - Numerical

# %%
data = {
    "Salary" : [25000, 30000, 37000, 28000, 39000, 48000, 55000, 52000, 35000, 26000, 27000, 31000, 33000, 29000, 40000, 36000, 34000, 45000, 47000, 50000]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   37000
# 3   28000
# 4   39000

# %%
df.shape
# Out:
# (20, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  20 non-null     int64
# dtypes: int64(1)
# memory usage: 292.0 bytes

# %%
# Line PLot:

plt.plot(df["Salary"], color = "blue", marker = "*", linestyle = ":", linewidth = "3")
plt.grid()
plt.show()

# %%
# Histogram

plt.hist(df["Salary"], bins = 10, color = "green")
plt.show()

# %%
# Boxplot:

plt.boxplot(df["Salary"])
plt.show()

# %%
df.loc[20] = [0]

# %%
plt.boxplot(df["Salary"])
plt.show()

# %%
df.drop(index = 20, inplace = True)

# %%
df.shape
# Out:
# (20, 1)

# %% [markdown]
# # Univariate: Categorical

# %%
df["dept"] = ['HR', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'HR', 'Finance', 'IT', 'HR'] * 2

# %%
df.head()
# Out:
#    Salary     dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HR
# 4   39000  Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  20 non-null     int64
#  1   dept    20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 480.0+ bytes

# %%
# Pie chart:

count = df["dept"].value_counts()
count
# Out:
# dept
# HR         8
# IT         6
# Finance    6
# Name: count, dtype: int64

# %%
plt.pie(count, labels = count.index, autopct= "%1.2f", explode = [0, 0.1, 0.2])
plt.axis("equal")
plt.show()

# %%
# Countplot

plt.bar(count.index, count, color = ["green", "yellow", "red"])
plt.show()

# %% [markdown]
# # Bivariate - numerical- numerical

# %%
df.head()
# Out:
#    Salary     dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HR
# 4   39000  Finance

# %%
df["Age"] = [22, 25, 29, 24, 30, 35, 40, 36, 28, 22, 23, 25, 26, 24, 31, 29, 27, 33, 35, 38]

# %%
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   22
# 1   30000       IT   25
# 2   37000  Finance   29
# 3   28000       HR   24
# 4   39000  Finance   30

# %%
# Scatter Plot:

plt.scatter(df["Age"], df["Salary"], color = "blue")
plt.show()

# %%
sort_age = df.sort_values("Age")

# %%
sort_age.head()
# Out:
#     Salary dept  Age
# 0    25000   HR   22
# 9    26000   HR   22
# 10   27000   HR   23
# 3    28000   HR   24
# 13   29000   HR   24

# %%
sort_age
# Out:
#     Salary     dept  Age
# 0    25000       HR   22
# 9    26000       HR   22
# 10   27000       HR   23
# 3    28000       HR   24
# 13   29000       HR   24
# 11   31000       IT   25
# 1    30000       IT   25
# 12   33000  Finance   26
# 16   34000       HR   27
# 8    35000       IT   28
# 15   36000       IT   29
# 2    37000  Finance   29
# 4    39000  Finance   30
# 14   40000  Finance   31
# 17   45000  Finance   33
# 5    48000       IT   35
# 18   47000       IT   35
# 7    52000  Finance   36
# 19   50000       HR   38
# 6    55000       HR   40

# %%
sort_age = df.sort_values("dept")

# %%
sort_age.head()
# Out:
#     Salary     dept  Age
# 17   45000  Finance   33
# 2    37000  Finance   29
# 4    39000  Finance   30
# 14   40000  Finance   31
# 7    52000  Finance   36

# %%
# Line plot:

plt.plot(sort_age["Age"], df["Salary"], color = "green", marker = "*", linewidth = "2")
plt.grid()
plt.show()

# %%
# Bar chart:

plt.bar(sort_age["Age"], df["Salary"], color = "green")
plt.show()

# %% [markdown]
# # Bivariate: Numerical - categorical

# %%
hr_sal = df[df["dept"] == "HR"]["Salary"]
hr_sal
# Out:
# 0     25000
# 3     28000
# 6     55000
# 9     26000
# 10    27000
# 13    29000
# 16    34000
# 19    50000
# Name: Salary, dtype: int64

# %%
fin_sal = df[df["dept"] == "Finance"]["Salary"]
fin_sal
# Out:
# 2     37000
# 4     39000
# 7     52000
# 12    33000
# 14    40000
# 17    45000
# Name: Salary, dtype: int64

# %%
# Boxplot:

hr_sal = [50000, 52000, 55000, 53000, 56000]  # Replace with your actual data
it_sal = [70000, 72000, 75000, 74000, 76000]  # Replace with your actual data
fin_sal = [65000, 67000, 68000, 69000, 70000]  # Replace with your actual data

# Boxplot
plt.boxplot([hr_sal, it_sal, fin_sal], labels=["HR", "IT", "Finance"])
plt.title("Salary Distribution by Department")
plt.ylabel("Salary")
plt.show()
# Out:
# /tmp/ipython-input-49-3878943624.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal, it_sal, fin_sal], labels=["HR", "IT", "Finance"])

# %%
# pie chart:

salary_by_dept = df.groupby("dept")["Salary"].sum()
salary_by_dept
# Out:
# dept
# Finance    246000
# HR         274000
# IT         227000
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept, labels = salary_by_dept.index, autopct = "%1.2f", shadow = True, explode = [0.1, 0, 0.1])
plt.axis("equal")
plt.show()

# %%
# bar plot

hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(fin_sal)/len(fin_sal)

# %%
plt.bar(["HR", "IT", "Finance"], [hr_mean, it_mean, fin_mean], color = ["green", "yellow", "red"])
plt.grid()
plt.show()

# %% [markdown]
# # Multivariate Analysis: 3 numerical columns

# %%
df["experience"] =  [1, 2, 4, 1.5, 5, 8, 12, 10, 4, 1, 1.2, 2, 3, 1.8, 5.5, 4.5, 3.2, 7, 8, 10]

# %%
df.head()
# Out:
#    Salary     dept  Age  experience
# 0   25000       HR   22         1.0
# 1   30000       IT   25         2.0
# 2   37000  Finance   29         4.0
# 3   28000       HR   24         1.5
# 4   39000  Finance   30         5.0

# %%
# Bubble PLot:

plt.scatter(df["Age"], df["Salary"], s = df["experience"]*50, color = "skyblue", edgecolors= "black")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # 2 numerical and 1 categorical column:

# %%
plt.scatter(df["Age"], df["Salary"], c = df["dept"].map({"HR": "yellow", "IT":"blue", "Finance": "green"}))
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary vs Dept")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-57-842139155.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
color = {"HR": "yellow", "IT":"blue", "Finance": "green"}

for dept, color in color.items():
    df_dept = df[df["dept"] == dept]
    plt.scatter(df_dept["Age"], df_dept["Salary"], c = color, label = dept)

plt.legend()

# %% [markdown]
# # Object Oriented API

# %%
fig, axs = plt.subplots(1,3, figsize = (15,5))

# Line plot

axs[0].plot(sort_age["Age"], df["Salary"], color = "red", marker = "*", linewidth = "2", markersize = 2)
axs[0].grid()
axs[0].set_title("Line Plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")

# histogram:

axs[1].hist(df["Salary"], bins = 5, color = "skyblue")
axs[1].set_title("Histogram")
axs[1].set_xlabel("Salary")
axs[1].set_ylabel("Frequency")


# Boxplot:

axs[2].boxplot(df["Salary"])
axs[2].set_title("Boxplot")
axs[2].set_xlabel("Salary")

plt.savefig("multipleplots.png")
plt.show()

# %%
data2 = {
    'Year': [2020, 2021, 2022, 2023],
    'Sales': [100, 150, 200, 250],
    'Profit': [20, 30, 40, 50],
    'Expenses': [80, 120, 160, 200]
}

# %%
df2 = pd.DataFrame(data2)

# %%
plt.plot(df2["Year"], df2["Sales"], label = "Sales")
plt.plot(df2["Year"], df2["Profit"], label = "Profit")
plt.plot(df2["Year"], df2["Expenses"], label = "Expenses")

plt.title("Financial Analysis")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# # 3-D Plot:

# %%
ax = plt.axes(projection = "3d")

ax.scatter(df["Age"], df["Salary"], df["experience"])
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")
plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(df, x='Age', y='Salary', z='experience', title='3D Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0e760705-6c3f-4219-8884-3097f6a9faee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e760705-6c3f-4219-8884-3097f6a9faee")) {                    Plotly.newPlot(                        "0e760705-6c3f-4219-8884-3097f6a9faee",                        [{"hovertemplate":"Age=%{x}\u003cbr\u003eSalary=%{y}\u003cbr\u003eexperience=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[22,25,29,24,30,35,40,36,28,22,23,25,26,24,31,29,27,33,35,38],"y":[25000,30000,37000,28000,39000,48000,55000,52000,35000,26000,27000,31000,33000,29000,40000,36000,34000,45000,47000,50000],"z":[1.0,2.0,4.0,1.5,5.0,8.0,12.0,10.0,4.0,1.0,1.2,2.0,3.0,1.8,5.5,4.5,3.2,7.0,8.0,10.0],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5 ...
